# %% [markdown]
# <a href="https://colab.research.google.com/github/HiroshiATakano/GitHub/blob/master/Pandas_100_knocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import pandas as pd
import tempfile
from glob import glob

# %%
path = os.getcwd()

try:
    os.chdir(path + "/drive/My Drive/Pandas 100 knocks")
except:
    pass

os.getcwd()
# Out:
# '/content/drive/My Drive/Pandas 100 knocks'

# %%
for curDir, dirs, files in os.walk('./Data'):
  print(curDir)
  for file in files:
    print(os.path.join(curDir,file))
# Out:
# ./Data
# ./Data/working
# ./Data/working/trick8data1.csv
# ./Data/working/trick8data3.csv
# ./Data/working/trick8data2.csv
# ./Data/working/trick18data.csv.gz
# ./Data/working/trick18data.csv.zip
# ./Data/input
# ./Data/input/ｱﾝｹｰﾄﾃﾞｰﾀ_0708水本.xlsx
# ./Data/input/sample_pandas_normal.csv
# ./Data/input/trick58data
# ./Data/input/trick58data/2015_Air_quality_in_northern_Taiwan.csv
# ./Data/input/titanic
# ./Data/input/titanic/genderclassfare.csv
# ./Data/input/titanic/train.csv
# ./Data/input/titanic/gender_submission.csv
# ./Data/input/titanic/test.csv
# ./Data/input/imdbmovies
# ./Data/input/imdbmovies/IMDB-Movie-Data.csv
# ./Data/input/drinks-by-country
# ./Data/input/drinks-by-country/drinksbycountry.csv
# ./Data/input/us-accidents
# ./Data/input/imdb-data
# ./Data/input/imdb-data/IMDB-Movie-Data.csv

# %%
with tempfile.TemporaryFile(dir=".") as f:
  f.write(b"Helo, World!")
  f.seek(0)
  print (f.read())
# Out:
# b'Helo, World!'

# %%
def print_files():
  print(os.walk('./Data/input'))
  for dirname, _, filenames in os.walk('./Data/input'):
    for filename in filenames:
      print(os.path.join(dirname,filename))

def generate_sample_data():
  number_of_rows = 20
  num_cols = 7
  cols = list("ABCDEFG")
  df = pd.DataFrame(np.random.randint(1,20,size=(number_of_rows, num_cols)), columns=cols)
  df.index = pd.util.testing.makeIntIndex(number_of_rows)
  return df

def generate_sample_data_datetime():
  number_of_rows = 366*24
  num_cols = 2
  cols = ["sales","customers"]
  df = pd.DataFrame(np.random.randint(1,20,size=(number_of_rows, num_cols)), columns=cols)
  df.index = pd.util.testing.makeDateIndex(number_of_rows, freq="H")
  return df

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactiveity = "all"

# %% [markdown]
# ## Trick 1: Add a prefix or suffix to all columns

# %%
df = generate_sample_data()[:5]
print("Original df")
display(df)

print("Add prefix")
display(df.add_prefix("1_"))

print("Add suffix")
display(df.add_suffix("_Z"))
# Out:
# Original df
#     A   B   C   D   E   F   G
# 0  16  18   8  14   4  12   6
# 1  16  10  18  16   3  16  14
# 2   9   9   1  13   1  12   4
# 3  11   6   3  12  19  13   9
# 4  19   6   1   4   7  12   9
# Add prefix
#    1_A  1_B  1_C  1_D  1_E  1_F  1_G
# 0   16   18    8   14    4   12    6
# 1   16   10   18   16    3   16   14
# 2    9    9    1   13    1   12    4
# 3   11    6    3   12   19   13    9
# 4   19    6    1    4    7   12    9
# Add suffix
#    A_Z  B_Z  C_Z  D_Z  E_Z  F_Z  G_Z
# 0   16   18    8   14    4   12    6
# 1   16   10   18   16    3   16   14
# 2    9    9    1   13    1   12    4
# 3   11    6    3   12   19   13    9
# 4   19    6    1    4    7   12    9

# %% [markdown]
# ## Trick 2: Reverse order of a df

# %%
print("Reverse columns order")
display(df.loc[:, ::-1])

print("Reverse index order")
display(df.loc[::-1])

print("Reverse row order and reset index")
display(df.loc[::-1].reset_index(drop=True))
# Out:
# Reverse columns order
#     G   F   E   D   C   B   A
# 0   6  12   4  14   8  18  16
# 1  14  16   3  16  18  10  16
# 2   4  12   1  13   1   9   9
# 3   9  13  19  12   3   6  11
# 4   9  12   7   4   1   6  19
# Reverse index order
#     A   B   C   D   E   F   G
# 4  19   6   1   4   7  12   9
# 3  11   6   3  12  19  13   9
# 2   9   9   1  13   1  12   4
# 1  16  10  18  16   3  16  14
# 0  16  18   8  14   4  12   6
# Reverse row order and reset index
#     A   B   C   D   E   F   G
# 0  19   6   1   4   7  12   9
# 1  11   6   3  12  19  13   9
# 2   9   9   1  13   1  12   4
# 3  16  10  18  16   3  16  14
# 4  16  18   8  14   4  12   6

# %%
df
# Out:
#     A   B   C   D   E   F   G
# 0  16  18   8  14   4  12   6
# 1  16  10  18  16   3  16  14
# 2   9   9   1  13   1  12   4
# 3  11   6   3  12  19  13   9
# 4  19   6   1   4   7  12   9

# %%
pd.util.testing.makeMixedDataFrame()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
df = pd.read_csv("./Data/input/titanic/train.csv")
print("Original df")
display(df.head())
# Out:
# Original df
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Trick 3: Filter a df by multiple conditions (isin and iverse using ~)

# %%
df = generate_sample_data()[:5]
df["A"] = np.arange(5)+1
display(df)

display(df[(df["A"]==1) | (df["A"]==3)])

display(df[df["A"].isin([1,3])])

display(df[~df["A"].isin([1,3])])
# Out:
#    A   B   C   D   E   F   G
# 0  1  16   4   7   2  11  18
# 1  2   7  12  11   5   1   4
# 2  3   4   4   2  16   5  19
# 3  4  19   9   4   8   1   2
# 4  5  17  10   6  18   9  17
#    A   B  C  D   E   F   G
# 0  1  16  4  7   2  11  18
# 2  3   4  4  2  16   5  19
#    A   B  C  D   E   F   G
# 0  1  16  4  7   2  11  18
# 2  3   4  4  2  16   5  19
#    A   B   C   D   E  F   G
# 1  2   7  12  11   5  1   4
# 3  4  19   9   4   8  1   2
# 4  5  17  10   6  18  9  17

# %% [markdown]
# ## Trick 4: Select columns by dtype

# %%
df = generate_sample_data_datetime()[:10].reset_index()
df["string_col"] = list("ABCDEABCDE")
df["sales"] = df["sales"].astype("float")
display(df)

display(df.info())

display(df.select_dtypes(include="number"))

display(df.select_dtypes(include="object"))

display(df.select_dtypes(include=["datetime","timedelta"]))

display(df.select_dtypes(include=["float"]))
# Out:
#                 index  sales  customers string_col
# 0 2000-01-01 00:00:00   18.0         13          A
# 1 2000-01-01 01:00:00   15.0          1          B
# 2 2000-01-01 02:00:00    7.0         16          C
# 3 2000-01-01 03:00:00    7.0         15          D
# 4 2000-01-01 04:00:00   10.0         17          E
# 5 2000-01-01 05:00:00    9.0          9          A
# 6 2000-01-01 06:00:00    2.0         14          B
# 7 2000-01-01 07:00:00   11.0          6          C
# 8 2000-01-01 08:00:00   15.0         17          D
# 9 2000-01-01 09:00:00   14.0          4          E
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       10 non-null     datetime64[ns]
#  1   sales       10 non-null     float64
#  2   customers   10 non-null     int64
#  3   string_col  10 non-null     object
# ...
